# %% [markdown]
# # Definición del problema de negocio - Justificación.

# %% [markdown]
# ## 1️⃣ Consigna oficial del proyecto - hackathon.

# %% [markdown]
# "Desarrollar una solución predictiva capaz de estimar si un vuelo va a **despegar** a tiempo o con retraso."

# %% [markdown]
# ###Análisis semántico de la consigna.

# %% [markdown]
# - La consigna usa lenguaje natural, no técnico.
#
# - El verbo despegar: En lenguaje natural se asocia a salidas de vuelo, pero no define qué se entiende por retraso, cuántos minutos constituye un retraso, si se trata de una definición para uso operacional, estadístico o jurídico.
#
# - Describe el objetivo general del producto, pero: no fija un estandar de medición, tampoco limita explícitamente el modelo a un único enfoque de negocio.

# %% [markdown]
# La frase: "**Despegar** a tiempo o con retraso" debe interpretarse como:
#
# - Una forma accesible de describir el problema de puntualidad de vuelos, no como una definición técnica cerrada.
#
# - Tampoco debe considerarse como una restricción metodológica para el equipo de Data Science.

# %% [markdown]
# ✅ **Primera conclusión.**
#
# *"La consigna habilita, pero no impone, un enfoque específico."*
#
#   El equipo debe definir explícitamente que entiende por "retraso", ya que la consigna no lo define desde ningún punto de vista técnico o normativo.

# %% [markdown]
# ##2️⃣ Restricción clave: el dataset disponible.

# %% [markdown]
# El proyecto cuenta con un dataset de:
#
# - Vuelos domésticos en EE.UU,
#
# - Publicados por Bureau of Transportation Statistics (BTS),
#
# - Organismo dependiente de U.S. Department of Transportation.

# %% [markdown]
# ####Implicancia directa del dataset.

# %% [markdown]
# El dataset:
# - No es neutral, fue construido por criterios regulatorios específicos,
#
# - Incorpora definiciones claras de puntualidad y retraso.
#
# El BTS utiliza el estandar de:
#
# - Retraso en la llegada ≥ 15 minutos, para la medición de desempeño (on-time perfomance)

# %% [markdown]
# ####Decisión metodológica implícita.

# %% [markdown]
# Ignorar la definición incorporada en el dataset implicaría:
#
# - Perder coherencia entre datos y modelo.
#
# - Introducir una definición arbitraria.
#
# - Reducir la trazabilidad y defendibilidad del proyecto.

# %% [markdown]
# ✅ **Segunda conclusión.**
#
# La definición de problema debe ser consistente con la fuente oficial del dataset, para asegurar coherencia, trazabilidad y reproducibilidad del modelo.

# %% [markdown]
# ## 3️⃣Análisis del marco normativo aplicable al proyecto.

# %% [markdown]
# Al indagar sobre la normativa federal estadounidense, se observa que:
#
# - No existe una única definición jurídica de "retraso".
#
# - La definición varia según el propósito regulatorio.

# %% [markdown]
# ####Escenarios jurídicos identificados.

# %% [markdown]
# | Escenario                     | Norma aplicable | Criterio         | Umbral                                  | Finalidad                           |
# | ----------------------------- | --------------- | ---------------- | --------------------------------------- | ----------------------------------- |
# | Medición estadística oficial  | 14 CFR Part 234 | Llegada          | ≥ 15 min                                | Medición de puntualidad (BTS / DOT) |
# | Información al pasajero       | 14 CFR §259.8   | Salida o llegada | ≥ 30 min                                | Deber de información                |
# | Derechos legales del pasajero | 14 CFR §260.2   | Salida o llegada | ≥ 3h (doméstico) / ≥ 6h (internacional) | Reembolsos y cambios contractuales  |

# %% [markdown]
# Cada definición es válida, pero responde a:
#
# - Objetivos distintos.
#
# - Actores distintos,
#
# - Niveles distintos de impacto.
#
#
# Por lo tanto, elegir una definición es una decisión de diseños, no un dato dado.

# %% [markdown]
# ✅ Tercera conclusión.
#
# El concepto de "retraso" es contextual y depende del objetivo del modelo; por lo tanto, el quipo debe seleccionar conscientemente la definición más adecuada para el MVP.

# %% [markdown]
# ##4️⃣ Evaluación de escenarios desde el punto de vista del MVP.

# %% [markdown]
# ❌ Implementar múltiples definiciones de retraso.
#
# Esto implicaría:
#
# - Entrenar múltiples modelos  o targets.
#
# - Mayor complejidad técnica.
#
# - Mayor riesgo de errores.
#
# - Mayor dificultad para explicar resultados.
#
# - Sobrecargar el MVP.

# %% [markdown]
# 🎯 Qué es más sabio: Adoptar una definición base y escalable.
#
# Esto implica:
#
# - **Elegir una definición principal, bien documentada.**
#
# - **Construir un pipeline simple y robusto.**
#
# - **Dejar explícito que otros escenarios pueden evaluarse a futuro.**
#
# - **Priorizar claridad, aprendizaje y demostrabilidad.**

# %% [markdown]
# ✅ Cuarta conclusión.
#
# Para el MVP es preferible adoptar una definición base clara y documentada, en lugar de cubrir múltiples escenarios simultáneamente.

# %% [markdown]
# ##5️⃣ Decisión propuesta para el equipo (de estar de acuerdo se cambiará a : )

# %% [markdown]
# Como definición principal de retraso elegir:
#
#  *" **Llegada con 15 minutos o más de retraso respecto del horario programado, conforme al estándar oficial del DOT/ BTS.** "*
#
# Razones clave:
#
# - **Estándar oficial de la industria.** Es la métrica utilizada por la autoridad reguladora y por los datasets públicos.
#
# - **Alineación directa con el dataset.** Evita redefinir artificialmente el target.
#
# - **Evento suficientemente frecuente.** Facilita el entrenamiento y reduce problemas de desbalance.
#
# - **Facilidad de interpretación y evaluación.** Resultados claros para el jurado.
#
# - **Escalabilidad sin rediseñar el modelo.** Las mismas variables explicativas permiten: analizar los tres escenarios jurídicos de definición de retrasos en la industria de aviación.
#
#
# *"Adaptar el producto a distintos clientes, sin cambiar el pipeline, solo el criterio de análisis."* De manera que si se cambia la definición de retraso a ≥ 30 min se adaptaría el modelo a una experiencia de usuario (pasajeros) o si se usa se cambia la definición a ≥ 3h (doméstico) / ≥ 6h (internacional) se adaptaría el modelo a los gastos operativos del usuario (aerolíneas). Cubriendo así los 3 posibles clientes en el mercado: aeropuertos, aerolíneas y pasajeros.
#
# **Enfoque de producto:**
#
# *"El modelo no queda atado a un único cliente ni a una única regulación, sino que se construye sobre una base estandar reutilizable."*
#
# Este sería el principal valor agregado de nuestro modelo de predicción: la escalabilidad y adaptabilidad a los 3 potenciales clientes en el mercado y principales usuarios del producto.

# %% [markdown]
# ✅ Quinta conclusión:
#
# La definición propuesta es técnica, jurídica y metodológicamente defendible, y permite construir un modelo escalable con enfoque de producto.

# %% [markdown]
# ##6️⃣ Resultado propuesto: redacción final del problema de negocio.

# %% [markdown]
# **"FlightOnTime"** es concebido como un proyecto de modelado predictivo cuyo propósito es proveer una herramienta de apoyo a la toma de decisiones en el contexto de la aviación civil. Tiene como objetivo principal anticipar si un vuelo presentará retrasos operativos a partir del análisis de información histórica de vuelos comerciales domésticos de Estados Unidos correspondientes al año 2024.

# %% [markdown]
# #Definición del problema de machine learning - Justificación.

# %% [markdown]
# #¡¡¡ OJO !!!
# Acá iría el problema de negocio transformado en un problema de machine learning. Ya lo tengo, solo me falta digitarlo.  Cualquier consulta sobre la justificación de la definición de problema que hice, me la pueden realizar en la próxima reunión.
